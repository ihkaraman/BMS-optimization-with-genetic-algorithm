# %%
from genetic_algorithm import GeneticAlgorithm
import numpy as np

# %%
population_size = 20

# crossover parameters
crossover_probability = 0.6
crossover_type = 1
fitness_function = 'cost'

# selection parameters
elitism_ratio = 0.2 # must be even!
max_parent_allowance = 0.125

#mutation parameters
mutation_probability = 0.1 
mutation_rate = 0.1

# algorithm settings
max_iter = 300 
k = 10 
stop_thrs = 10
mutation_level = 0.2

run_num = 3

individual_size = 120

data = {'load': r'data\miris_load.csv', 'pv': r'data\miris_pv.csv'}

# %%
parameters = [
data, population_size, k,\
fitness_function,  crossover_type, crossover_probability, \
elitism_ratio, max_parent_allowance, \
mutation_probability, mutation_rate, max_iter, individual_size,\
stop_thrs, mutation_level \
]

# %%
ga = GeneticAlgorithm(parameters)

# %%
ga.run()

# %%
ga.print_results()
# Out:
# ---------------------------------------------------
# Algorithm finished...
#
# Stopping condition: Max iterations reached!
# ----------------
# Best cost function:  10.103083848224356
# ----------------
# Best individual:
# [155.20000000000002 96.0 52.531200000000005 210.0 227.51999999999998
#  183.29600000000005 138 115.19999999999999 27.52 186.88000000000002
#  249.93792000000002 112.8 103.2192 5.76 118.08 210 146.88
#  205.60000000000002 308.0 285.6 280.32 308.8 341 298 288.8 269
#  227.32800000000003 105.11999999999999 124.16000000000003
#  106.24000000000001 72.0 81.6 162.0 265 222.56640000000002
#  110.59200000000001 270.40000000000003 284 367 182.78400000000002
#  153.60000000000002 248.0 223.2 151 97.48480000000002 38.01599999999999
#  42.0 150.0 270 221 261.2736 277.6 314 195.20000000000002 52.8 99.2 185
#  327 358 367.2 213.11999999999998 186.0 176 246.4 284 298 302 249.6 79.2
#  88.32 175 141.12 294.0 324 282.40000000000003 291 235.2 205.056 209
# ...

# %%
ga.plot_cost()

# %%
ga.results
# Out:
# {'stop_cond': 'Max iterations',
#  'iter num': 300,
#  'min_cost': 10.103083848224356,
#  'best_soln': array([155.20000000000002, 96.0, 52.531200000000005, 210.0,
#         227.51999999999998, 183.29600000000005, 138, 115.19999999999999,
#         27.52, 186.88000000000002, 249.93792000000002, 112.8, 103.2192,
#         5.76, 118.08, 210, 146.88, 205.60000000000002, 308.0, 285.6,
#         280.32, 308.8, 341, 298, 288.8, 269, 227.32800000000003,
#         105.11999999999999, 124.16000000000003, 106.24000000000001, 72.0,
#         81.6, 162.0, 265, 222.56640000000002, 110.59200000000001,
#         270.40000000000003, 284, 367, 182.78400000000002,
#         153.60000000000002, 248.0, 223.2, 151, 97.48480000000002,
#         38.01599999999999, 42.0, 150.0, 270, 221, 261.2736, 277.6, 314,
#         195.20000000000002, 52.8, 99.2, 185, 327, 358, 367.2,
#         213.11999999999998, 186.0, 176, 246.4, 284, 298, 302, 249.6, 79.2,
# ...

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-4f76a9dad686> in <module>
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
from calculate_fitness import CalculateFitness

# %%
cf = CalculateFitness(data)

# %%
random_array = np.random.randint(0, 100,  size = (20, 120))
random_array

# %%
for i in random_array:
    print(cf.fitness(i))

# %%
cf1 = CalculateFitness(data)
cf1

# %%
cf2 = CalculateFitness(data)
cf2
